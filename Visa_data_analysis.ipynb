# %%
import pandas as pd
path=r"/Users/kglobaltechnologies/Downloads/Visadataset.csv"
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.head(10)
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 0  EZYV01           Asia           High School                  N
# 1  EZYV02           Asia              Master's                  Y
# 2  EZYV03           Asia            Bachelor's                  N
# 3  EZYV04           Asia            Bachelor's                  N
# 4  EZYV05         Africa              Master's                  Y
# 5  EZYV06           Asia              Master's                  Y
# 6  EZYV07           Asia            Bachelor's                  N
# 7  EZYV08  North America            Bachelor's                  Y
# 8  EZYV09           Asia            Bachelor's                  N
# 9  EZYV10         Europe             Doctorate                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# ...

# %%
visa_df.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %%
visa_df.isna()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_df.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_df.shape
# Out:
# (25480, 12)

# %%
visa_df.size
# Out:
# 305760

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
len(visa_df.columns)
# Out:
# 12

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
len(visa_df.dtypes)
# Out:
# 12

# %%
types=dict(visa_df.dtypes)
cat_columns=[key for key,value in types.items() if value=='object']
num_columns=[key for key,value in types.items() if value!='object']
print(cat_columns)
print()
print(num_columns)
# Out:
# ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']
#
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
cat_columns=visa_df.select_dtypes(include='object').columns

# %%
cat_columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
num_columns=visa_df.select_dtypes(exclude='object').columns
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
types=dict(visa_df.dtypes)
for i,j in types.items():
    print(f'{i} : {j}')
# Out:
# case_id : object
# continent : object
# education_of_employee : object
# has_job_experience : object
# requires_job_training : object
# no_of_employees : int64
# yr_of_estab : int64
# region_of_employment : object
# prevailing_wage : float64
# unit_of_wage : object
# full_time_position : object
# case_status : object

# %%
dict(visa_df.dtypes).values()
# Out:
# dict_values([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('int64'), dtype('int64'), dtype('O'), dtype('float64'), dtype('O'), dtype('O'), dtype('O')])

# %%
cols,data_types=[],[]
for key,value in dict(visa_df.dtypes).items():
    cols.append(key)
    data_types.append(value)
pd.DataFrame(zip(cols,data_types),
             columns=['columns','data_types'])
# Out:
#                   columns data_types
# 0                 case_id     object
# 1               continent     object
# 2   education_of_employee     object
# 3      has_job_experience     object
# 4   requires_job_training     object
# 5         no_of_employees      int64
# 6             yr_of_estab      int64
# 7    region_of_employment     object
# 8         prevailing_wage    float64
# 9            unit_of_wage     object
# 10     full_time_position     object
# 11            case_status     object

# %%
visa_df['continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df[['continent']]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
visa_df[['continent']].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
visa_df[['continent','unit_of_wage']].value_counts()
# Out:
# continent      unit_of_wage
# Asia           Year            15338
# Europe         Year             3568
# North America  Year             2705
# Asia           Hour             1311
# South America  Year              679
# Africa         Year              504
# North America  Hour              495
# Oceania        Year              168
# South America  Hour              157
# Asia           Week              154
# Europe         Hour              140
# North America  Week               75
# Asia           Month              58
# Africa         Hour               36
# Oceania        Hour               18
# North America  Month              17
# Europe         Week               17
# South America  Week               14
# Africa         Week                8
# Europe         Month               7
# Oceania        Week                4
# Africa         Month               3
# Oceania        Month               2
# South America  Month               2
# Name: count, dtype: int64

# %%
visa_df['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df['continent']
con=visa_df['continent']=='Asia'
len(visa_df[con])
# Out:
# 16861

# %%
visa_df['continent']
con=visa_df['continent']=='Africa'
len(visa_df[con])
# Out:
# 551

# %%
con=visa_df['continent']=='Oceania'
len(visa_df[con])
# Out:
# 192

# %%
for i in visa_df['continent'].unique():
    con=visa_df['continent']==i
    count=(len(visa_df[con]))
    print(f'The number of applicants from {i} are {count}')
    print()
# Out:
# The number of applicants from Asia are 16861
#
# The number of applicants from Africa are 551
#
# The number of applicants from North America are 3292
#
# The number of applicants from Europe are 3732
#
# The number of applicants from South America are 852
#
# The number of applicants from Oceania are 192

# %%
list1=[]
continents=visa_df['continent'].unique()
for i in continents:
    con=visa_df['continent']==i
    list1.append(len(visa_df[con]))
    
cols=['continents','Number of applicants']  
df=pd.DataFrame(zip(continents,list1),columns=cols)
x=df.to_csv('continent_df.csv',index=False)

# %%
y=pd.read_csv('continent_df.csv')
y
# Out:
#       continents  Number of applicants
# 0           Asia                 16861
# 1         Africa                   551
# 2  North America                  3292
# 3         Europe                  3732
# 4  South America                   852
# 5        Oceania                   192

# %%
import matplotlib.pyplot as plt
plt.bar('continents','Number of applicants',data=y)
plt.title('Bar Chart')
plt.xlabel('continents')
plt.ylabel('Number of applicants')
plt.savefig('Continents_bar_chart.jpg')
plt.show()

# %%
continents=visa_df['continent'].unique()
for i in visa_df['continent'].unique():
    con=visa_df['continent']==i
    count=(len(visa_df[con]))
    print(f'The number of applicants from {i} are {count}')
continent_df=pd.DataFrame(zip(continents,count),columns=['continent','number of applicants'])
continent_df.to_csv('continent_df.csv',index=False)
# Out:
# The number of applicants from Asia are 16861
# The number of applicants from Africa are 551
# The number of applicants from North America are 3292
# The number of applicants from Europe are 3732
# The number of applicants from South America are 852
# The number of applicants from Oceania are 192
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 6
#       4     count=(len(visa_df[con]))
#       5     print(f'The number of applicants from {i} are {count}')
# ----> 6 continent_df=pd.DataFrame(zip(continents,count),columns=['continent','number of applicants'])
#       7 continent_df.to_csv('continent_df.csv',index=False)
#
# TypeError: 'int' object is not iterable

# %%
import seaborn as sns

order_continents=['Asia','Europe','North America','South America','Africa','Oceania']
sns.countplot(data=visa_df,x='continent',order=order_continents)
plt.title('Bar chart')
plt.savefig('continents_bar_chart_seborn.jpg')
plt.show()

# %%
import pandas as pd
visa_path=r"/Users/kglobaltechnologies/Downloads/Visadataset.csv"
visa_df=pd.read_csv(visa_path)
visa_df

# %%
visa_df['continent']

# %%
visa_df['continent'].unique()

# %%
visa_df['continent'].unique()
con=visa_df['continent']=='Asia'
print(len(visa_df[con]))

# %%
continent_data=visa_df['continent'].unique()
list=[]
for i in visa_df['continent'].unique():
    con=visa_df['continent']==i
    c=len(visa_df[con])
    list.append(c)
    
    
continents_df=pd.DataFrame(zip(continent_data,list),columns=['continents','number'])

continents_df.to_csv('continents_dataframe.csv',index=False)
pd.read_csv('continents_dataframe.csv')

# %%
import matplotlib.pyplot as plt
plt.bar('continents','number',data=x)
plt.xlabel('continents')
plt.ylabel('number of people')
plt.savefig('continent_analysis.png')
plt.show()

# %%
import pandas as pd
types=dict(visa_df.dtypes)
cat_columns=[key for key,value in types.items() if value=='object']
cat_columns[1:]
# Out:
# ['continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
import matplotlib.pyplot as plt
for i in cat_columns[1:]:
    cat_df=visa_df[i].value_counts()
    keys=cat_df.keys()
    values=cat_df.values
    df=pd.DataFrame(zip(keys,values),columns=['column','number of applicants'])
    df.to_csv(f'{i}.csv',index=False)
    plt.bar('column','number of applicants',data=df)
    plt.show()

# %%
import matplotlib.pyplot as plt
for i in cat_columns[1:]:
    cat_df=visa_df[i].value_counts()
    keys=cat_df.keys()
    values=cat_df.values
    data1=pd.DataFrame(zip(keys,values),columns=['labels','count'])
    plt.bar('labels','count',data=data1)
    plt.savefig(f'{i}.jpg')
    plt.show()

# %%
types=dict(visa_df.dtypes)
cat_columns=[key for key,value in types.items() if value=='object']

data2=pd.DataFrame(cat_columns)
data2
# Out:
#                        0
# 0                case_id
# 1              continent
# 2  education_of_employee
# 3     has_job_experience
# 4  requires_job_training
# 5   region_of_employment
# 6           unit_of_wage
# 7     full_time_position
# 8            case_status

# %%
c=visa_df['continent'].unique()
count=[]
l=1
for i in c:
    condition=visa_df['continent']==i
    count.append(len(visa_df[condition]))
    l=l+1
df=pd.DataFrame(zip(c,count),columns=['continent','number'],index=[k for k in range(1,l)])
df
# Out:
#        continent  number
# 1           Asia   16861
# 2         Africa     551
# 3  North America    3292
# 4         Europe    3732
# 5  South America     852
# 6        Oceania     192

# %%
cdf=visa_df['continent'].value_counts()

# %%
cdf
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
keys=cdf.keys()

# %%
keys
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object', name='continent')

# %%
values=cdf.values
values
# Out:
# array([16861,  3732,  3292,   852,   551,   192])

# %%
df=pd.DataFrame(zip(keys,values))
df
# Out:
#                0      1
# 0           Asia  16861
# 1         Europe   3732
# 2  North America   3292
# 3  South America    852
# 4         Africa    551
# 5        Oceania    192

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %%
continents=visa_df['continent'].unique()
a=[]
for i in visa_df['continent'].unique():
    condition=visa_df['continent']==i
    a.append(len(visa_df[condition]))
    
df=pd.DataFrame(zip(continents,a),columns=['column','number'])
df
# Out:
#           column  number
# 0           Asia   16861
# 1         Africa     551
# 2  North America    3292
# 3         Europe    3732
# 4  South America     852
# 5        Oceania     192

# %%
visa_df['continent'].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
#normalize
cdf=visa_df['continent'].value_counts(normalize=True)
round(cdf*100,2)
# Out:
# continent
# Asia             66.17
# Europe           14.65
# North America    12.92
# South America     3.34
# Africa            2.16
# Oceania           0.75
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8,5))
order_continents=visa_df['continent'].value_counts().keys()
sns.countplot(data=visa_df,x='continent',order=order_continents)
plt.title('Bar chart')
plt.savefig('Continents_bar_chart_using_seaborn.jpg')
plt.show()

# %%
visa_df.value_counts().keys()
# Out:
# MultiIndex([(   'EZYV01',          'Asia', 'High School', 'N', 'N', ...),
#             ('EZYV25287',        'Europe',   'Doctorate', 'Y', 'N', ...),
#             ('EZYV25285',          'Asia',  'Bachelor's', 'N', 'N', ...),
#             ('EZYV25284',          'Asia',    'Master's', 'N', 'N', ...),
#             ('EZYV25283', 'South America', 'High School', 'Y', 'N', ...),
#             ('EZYV25282',          'Asia',    'Master's', 'Y', 'Y', ...),
#             ('EZYV25281', 'North America',  'Bachelor's', 'N', 'N', ...),
#             ('EZYV25280',          'Asia',    'Master's', 'Y', 'N', ...),
#             ( 'EZYV2528',          'Asia',  'Bachelor's', 'N', 'N', ...),
#             ('EZYV25279',          'Asia',  'Bachelor's', 'N', 'N', ...),
#             ...
#             ('EZYV17638', 'North America',  'Bachelor's', 'N', 'N', ...),
#             ('EZYV17637',          'Asia',  'Bachelor's', 'Y', 'N', ...),
# ...

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
# Out:
# <Axes: >

# %%
cat_columns=visa_df.value_counts()
cat_columns
# Out:
# case_id    continent      education_of_employee  has_job_experience  requires_job_training  no_of_employees  yr_of_estab  region_of_employment  prevailing_wage  unit_of_wage  full_time_position  case_status
# EZYV01     Asia           High School            N                   N                      14513            2007         West                  592.2029         Hour          Y                   Denied         1
# EZYV25287  Europe         Doctorate              Y                   N                      2705             1986         South                 3795.0500        Year          Y                   Certified      1
# EZYV25285  Asia           Bachelor's             N                   N                      2526             1962         West                  29596.5400       Year          Y                   Denied         1
# ...

# %%
import seaborn as sns
plt.figure(figsize=(15,3))
plt.subplot(1,2,1)
sns.countplot(data=visa_df,x='continent')
plt.subplot(1,2,2)
sns.countplot(data=visa_df,x='case_status')
# Out:
# <Axes: xlabel='case_status', ylabel='count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
cols=cat_columns[1:]
plt.figure(figsize=(16,14))
for i in range(len(cols)):
    plt.subplot(3,3,i+1)
    sns.countplot(x=cols[i],data=visa_df)
# Out:
# /var/folders/y0/j5yph2vj5h5382g7dl170p200000gn/T/ipykernel_869/448300366.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sns.countplot(x=cols[i],data=visa_df)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 7
#       5 for i in range(len(cols)):
#       6     plt.subplot(3,3,i+1)
# ----> 7     sns.countplot(x=cols[i],data=visa_df)
#
# File /opt/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
#    2941     raise ValueError("Cannot pass values for both `x` and `y`")
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15,3))
plt.subplot(1,2,1)
sns.countplot(x='continent',data=visa_df)

plt.subplot(1,2,2)
sns.countplot(x='education_of_employee',data=visa_df)

# %%
cds=visa_df['continent'].value_counts()
ax=cds.plot(kind='bar')
ax.bar_label(ax.containers[0])
plt.show()

## All three plots
import seaborn as sns
plt.figure(figsize=(8,5)) # 8 units X-axis, 5units y-axis
order_continents=visa_df['continent'].value_counts().keys()
sns.countplot(data=visa_df,
x='continent',
order=order_continents)
plt.title('Bar chart')
plt.savefig('Continents_bar_chart_using_seaborn.jpg')
plt.show()
################################################################################
import matplotlib.pyplot as plt
plt.bar('Continents', # Cat column X-axis
'Number of Applicants', # Num column: Height Y-axis
data=continents_df)
plt.title("Bar chart") # Title of the graph
plt.xlabel('Continents') # X-axis name

plt.ylabel('Number of Applicants') # Y-axis name

# %%
import pandas as pd
count_wage=len(visa_df['prevailing_wage'])
min_wage=min(visa_df['prevailing_wage'])
max_wage=max(visa_df['prevailing_wage'])
mean_wage=round(visa_df['prevailing_wage'].mean(),2)
median_wage=round(visa_df['prevailing_wage'].median(),2)
std_wage=round(visa_df['prevailing_wage'].std(),2)
values=[count_wage,min_wage,max_wage,mean_wage,median_wage,std_wage]
cols=['column','prevailing_wage']
i=['count','minimum value','maximum value','mean value','median','standard deviation']
wage_df=pd.DataFrame(zip(i,values),columns=cols)
wage_df

# %%
visa_df['prevailing_wage'].describe()

# %%
import numpy as np
np.percentile(visa_df['prevailing_wage'],25)

# %%
np.quantile(visa_df['prevailing_wage'],0.25)

# %%
np.quantile(visa_df['prevailing_wage'],0.5)

# %%
np.quantile(visa_df['prevailing_wage'],0.75)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 np.quantile(visa_df['prevailing_wage'],0.75)
#
# NameError: name 'np' is not defined

# %%
np.quantile(visa_df['prevailing_wage'],1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 np.quantile(visa_df['prevailing_wage'],1)
#
# NameError: name 'np' is not defined

# %%
round(np.percentile(visa_df['prevailing_wage'],0.5),2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 round(np.percentile(visa_df['prevailing_wage'],0.5),2)
#
# NameError: name 'np' is not defined

# %%
round(np.quantile(visa_df['prevailing_wage'],0.5),2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 round(np.quantile(visa_df['prevailing_wage'],0.5),2)
#
# NameError: name 'np' is not defined

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,4))
plt.bar('column','prevailing_wage',data=wage_df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 3
#       1 import matplotlib.pyplot as plt
#       2 plt.figure(figsize=(15,4))
# ----> 3 plt.bar('column','prevailing_wage',data=wage_df)
#       4 plt.show()
#
# NameError: name 'wage_df' is not defined

# %%
keys=visa_df['continent'].value_counts().keys()
values=visa_df['continent'].value_counts().values
plt.pie(values,explode=[0.1,0.1,0.1,0.2,0.2,0.2],labels=keys,radius=1,startangle=270,autopct='%0.2f%%')
plt.show()

# %%
#68.27% 
Mean=round(visa_df['prevailing_wage'].mean(),2)
Std=round(visa_df['prevailing_wage'].std(),2)
lb=Mean-1*Std
ub=Mean+1*Std
con1=visa_df['prevailing_wage']<ub
con2=visa_df['prevailing_wage']>lb
con3=con1&con2
visa_df[con3]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 5         EZYV06      Asia              Master's                  Y
# 6         EZYV07      Asia            Bachelor's                  N
# ...          ...       ...                   ...                ...
# 25473  EZYV25474      Asia            Bachelor's                  Y
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 1                         N             2412         2002
# ...

# %%
df1=pd.DataFrame()
for i in num_columns:
    Count=len(visa_df[i])
    Min=min(visa_df[i])
    Max=max(visa_df[i])
    Mean=visa_df[i].mean()
    Median=visa_df[i].median()
    Std=visa_df[i].std()
    p_25=round(np.percentile(visa_df[i],25),2)
    values=[Count,Min,Max,Mean,Median,Std,p_25]
    j=['count','minimum','maximum','mean','median','std','25_P']
    cols=[i]
    df2=pd.DataFrame(values,index=j,columns=cols)
    df1=pd.concat([df1,df2],axis=1)
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 9
#       7 Median=visa_df[i].median()
#       8 Std=visa_df[i].std()
# ----> 9 p_25=round(np.percentile(visa_df[i],25),2)
#      10 values=[Count,Min,Max,Mean,Median,Std,p_25]
#      11 j=['count','minimum','maximum','mean','median','std','25_P']
#
# NameError: name 'np' is not defined

# %%
#95.24%
Mean=round(visa_df['prevailing_wage'].mean(),2)
Std=round(visa_df['prevailing_wage'].std(),2)
lb=Mean-2*Std
ub=Mean+2*Std
con1=visa_df['prevailing_wage']<ub
con2=visa_df['prevailing_wage']>lb
con3=con1&con2
visa_df[con3]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
#99.7%
Mean=round(visa_df['prevailing_wage'].mean(),2)
Std=round(visa_df['prevailing_wage'].std(),2)
lb=Mean-3*Std
ub=Mean+3*Std
con1=visa_df['prevailing_wage']<ub
con2=visa_df['prevailing_wage']>lb
con3=con1&con2
visa_df[con3]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
wage_data=visa_df['prevailing_wage']
plt.hist(wage_data)
# Out:
# (array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#           21.]),
#  array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#         1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#         2.55368643e+05, 2.87289457e+05, 3.19210270e+05]),
#  <BarContainer object of 10 artists>)

# %%
for i in range(1,4):
    Mean=round(visa_df['prevailing_wage'].mean(),2)
    Std=round(visa_df['prevailing_wage'].std(),2)
    lb=Mean-i*Std
    ub=Mean+i*Std
    con1=visa_df['prevailing_wage']<=ub
    con2=visa_df['prevailing_wage']>=lb
    con3=con1&con2
    result=visa_df[con3]
result
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
import pandas as pd
results = [] 
for i in range(1, 4):
    mean_wage = round(visa_df['prevailing_wage'].mean(), 2)
    std_wage = round(visa_df['prevailing_wage'].std(), 2)
    lb = mean_wage - i * std_wage
    ub = mean_wage + i * std_wage
    condition = (visa_df['prevailing_wage'] >= lb) & (visa_df['prevailing_wage'] <= ub)
    new_df = visa_df[condition]
    results.append(new_df)
new_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
plt.hist(visa_df['prevailing_wage'])
# Out:
# (array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#           21.]),
#  array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#         1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#         2.55368643e+05, 2.87289457e+05, 3.19210270e+05]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns
wage_data=visa_df['prevailing_wage']
sns.boxplot(wage_data)
plt.title('prevailing wage')
plt.xlabel('Wages')
plt.show()

# %%
plt.figure(figsize=(14,3))
plt.subplot(1,2,1)
plt.hist(wage_data)
plt.subplot(1,2,2)
plt.boxplot(wage_data)
plt.show()

# %%
import numpy as np
wage_data=visa_df['prevailing_wage']
Mean=round(wage_data.mean(),2)
Std=round(wage_data.std(),2)
Q1=np.percentile(wage_data,25)
Q2=np.percentile(wage_data,50)
Q3=np.percentile(wage_data,75)
IQR=Q3-Q1
Upper_b=Q3+1.5*IQR
Lower_b=Q1-1.5*IQR
condition1=wage_data<Lower_b
condition2=wage_data>Upper_b
condition3=condition1|condition2
outliers_data=wage_data[condition3]
outliers_data
# Out:
# 14       220081.73
# 34       225569.73
# 130      247393.01
# 216      269321.68
# 221      219529.62
#            ...
# 25191    280482.51
# 25195    234308.77
# 25468    272715.74
# 25469    273772.47
# 25476    279174.79
# Name: prevailing_wage, Length: 427, dtype: float64

# %%
wage_data=visa_df['prevailing_wage']
Mean=round(wage_data.mean(),2)
Std=round(wage_data.std(),2)
Q1=np.percentile(wage_data,25)
Q2=np.percentile(wage_data,50)
Q3=np.percentile(wage_data,75)
IQR=Q3-Q1
Upper_b=Q3+1.5*IQR
Lower_b=Q1-1.5*IQR
condition1=wage_data>Lower_b
condition2=wage_data<Upper_b
condition3=condition1&condition2
non_outliers_data=visa_df[condition3]
non_outliers_data
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
plt.figure(figsize=(14,3))
plt.subplot(1,2,1)
plt.hist(non_outliers_data)
plt.subplot(1,2,2)
sns.boxplot(non_outliers_data)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
wage_data_non_outliers_df=non_outliers_data['prevailing_wage']
plt.figure(figsize=(14,3))
plt.suptitle('comparision with histogram and boxplot')
plt.subplot(2,2,1).hist(wage_data_non_outliers_df,bins=20)
plt.xlabel('Histogram')
plt.subplot(2,2,2).boxplot(wage_data_non_outliers_df,vert=False)
plt.xlabel=('Boxplot')
plt.show()

# %%
dict1={'marks':[74,86,95,96,86,88]}
df_1=pd.DataFrame(dict1,index=['maths','science','social','telugu','english','IT'])
df_1
# Out:
#          marks
# maths       74
# science     86
# social      95
# telugu      96
# english     86
# IT          88

# %%
df=df_1['marks']
ax=df.plot(kind='bar')
ax.bar_label(ax.containers[0])
plt.show()

# %%
import os
import matplotlib.pyplot as plt
path='./visa_df_columns_df'
all_files=os.listdir(path)
print(all_files)
# Out:
# ['has_job_experience.csv', 'requires_job_training.csv', 'full_time_position.csv', 'Continents_bar_chart_using_seaborn.jpg', 'region_of_employment.csv', 'continent.jpg', 'education_of_employee.jpg', 'unit_of_wage.csv', 'education_of_employee.csv', 'continents_bar_chart_seborn.jpeg', 'Continents_bar_chart.jpg', 'unit_of_wage.jpg', 'has_job_experience.jpg', 'requires_job_training.jpg', 'full_time_position.jpg', 'Continent.csv']

# %%
f=filter(lambda name:name.endswith('.csv'),all_files)
c=list(f)
print(c)
# Out:
# ['has_job_experience.csv', 'requires_job_training.csv', 'full_time_position.csv', 'region_of_employment.csv', 'unit_of_wage.csv', 'education_of_employee.csv', 'Continent.csv']

# %%
cdf=visa_df['continent'].value_counts().keys()
cdf
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object', name='continent')

# %%
case_status_df=visa_df['case_status'].value_counts()
case_status_df
# Out:
# case_status
# Certified    17018
# Denied        8462
# Name: count, dtype: int64

# %%
condition1=visa_df['continent']=='Asia'
condition2=visa_df['case_status']=='Certified'
condition3=condition1&condition2
len(visa_df[condition3])
# Out:
# 11012

# %%
condition1=visa_df['continent']=='Asia'
condition2=visa_df['case_status']=='Denied'
condition3=condition1&condition2
len(visa_df[condition3])
# Out:
# 5849

# %%
condition1=visa_df['continent']=='Africa'
condition2=visa_df['case_status']=='Certified'
condition3=condition1&condition2
len(visa_df[condition3])
# Out:
# 397

# %%
condition1=visa_df['continent']=='Africa'
condition2=visa_df['case_status']=='Denied'
condition3=condition1&condition2
len(visa_df[condition3])
# Out:
# 154

# %%
condition1=visa_df['continent']=='Europe'
condition2=visa_df['case_status']=='Certified'
condition3=condition1&condition2
len(visa_df[condition3])
# Out:
# 2957

# %%
condition1=visa_df['continent']=='Europe'
condition2=visa_df['case_status']=='Denied'
condition3=condition1&condition2
len(visa_df[condition3])
# Out:
# 775

# %%
for i in cdf:
    condition1=visa_df['continent']==i
    condition2=visa_df['case_status']=='Certified'
    condition3=condition1&condition2
    print(f'{len(visa_df[condition3])} members are certified from {i}')
# Out:
# 11012 members are certified from Asia
# 2957 members are certified from Europe
# 2037 members are certified from North America
# 493 members are certified from South America
# 397 members are certified from Africa
# 122 members are certified from Oceania

# %%
certified_list,denied_list=[],[]
for i in cdf:
    condition1=visa_df['continent']==i
    condition2=visa_df['case_status']=='Certified'
    condition3=condition1&condition2
    cert_count=len(visa_df[condition3])
    con1=visa_df['continent']==i
    con2=visa_df['case_status']=='Denied'
    con3=con1&con2
    den_count=len(visa_df[con3])
    print(f'{cert_count} members are certified from {i}')
    print(f'{den_count} members are denied from {i}')
    certified_list.append(cert_count)
    denied_list.append(den_count)
# Out:
# 11012 members are certified from Asia
# 5849 members are denied from Asia
# 2957 members are certified from Europe
# 775 members are denied from Europe
# 2037 members are certified from North America
# 1255 members are denied from North America
# 493 members are certified from South America
# 359 members are denied from South America
# 397 members are certified from Africa
# 154 members are denied from Africa
# 122 members are certified from Oceania
# 70 members are denied from Oceania

# %%
continents=visa_df['continent'].unique()

# %%
cols=['Certified','Denied']
df=pd.DataFrame(zip(certified_list,denied_list),index=continents,columns=cols)
df
# Out:
#                Certified  Denied
# Asia               11012    5849
# Africa              2957     775
# North America       2037    1255
# Europe               493     359
# South America        397     154
# Oceania              122      70

# %%
idx_columns=visa_df['continent']
data_columns=visa_df['case_status']
df1=pd.crosstab(idx_columns,data_columns)
df1
# Out:
# case_status    Certified  Denied
# continent
# Africa               397     154
# Asia               11012    5849
# Europe              2957     775
# North America       2037    1255
# Oceania              122      70
# South America        493     359

# %%
import matplotlib.pyplot as plt
df1.plot(kind='bar')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
idx_columns=visa_df['continent']
data_columns=[visa_df['education_of_employee'],visa_df['case_status']]
df2=pd.crosstab(idx_columns,data_columns)
df2
# Out:
# education_of_employee Bachelor's        Doctorate        High School         \
# case_status            Certified Denied Certified Denied   Certified Denied
# continent
# Africa                        81     62        43     11          23     43
# Asia                        4407   2761       780    143         676   1614
# Europe                      1040    259       788     58         162    328
# North America                641    584       207     51         210    191
# Oceania                       38     28        19      3          19     17
# South America                160    173        75     14          74     63
#
# education_of_employee  Master's
# case_status           Certified Denied
# continent
# Africa                      250     38
# Asia                       5149   1331
# Europe                      967    130
# North America               979    429
# Oceania                      46     22
# South America               184    109

# %%
df2.plot(kind='bar')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
num_columns=visa_df.select_dtypes(exclude='object').columns
visa_df[num_columns]
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage
# 0                14513         2007         592.2029
# 1                 2412         2002       83425.6500
# 2                44444         2008      122996.8600
# 3                   98         1897       83434.0300
# 4                 1082         2005      149907.3900
# ...                ...          ...              ...
# 25475             2601         2008       77092.5700
# 25476             3274         2006      279174.7900
# 25477             1121         1910      146298.8500
# 25478             1918         1887       86154.7700
# 25479             3195         1960       70876.9100
#
# [25480 rows x 3 columns]

# %%
import seaborn as sns
corr_data=visa_df.corr(numeric_only=True)
sns.heatmap(corr_data,annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
x=[i for i in range(-10,11)]
y=[i*i for i in x]
plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %%
col1=visa_df['no_of_employees']
col2=visa_df['yr_of_estab']
plt.scatter(col1,col2)
plt.plot(col1,col2)
plt.show()

# %%
num_columns=visa_df.select_dtypes(exclude='object').columns
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
import sklearn.preprocessing import labelencoder
le=labelencoder()
visa_df['case_status']=le.visa_df['case_status']

# %%
import numpy as np
visa_df=pd.read_csv("Visadataset.csv")
con=visa_df['case_status']=='Certified'
visa_df['case_status']=np.where(con,0,1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...
